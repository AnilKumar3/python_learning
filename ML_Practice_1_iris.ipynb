# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt
sns.set(color_codes=True)
# %matplotlib inline
df=pd.read_csv("iris.data.txt", header=-1)
col_name=['sepal length','sepal width','petal length','petal width','class']
df.columns = col_name

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dfs=sns.load_dataset('iris')

# %%
dfs.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
print (dfs.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(dfs, hue='species', size=5);

# %%
#iris data set is already there in seaborn
iris=sns.load_dataset('iris')
sns.pairplot(iris, hue='species')

# %%
print (iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print (iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(iris,hue='species',size=3)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline
iris=sns.load_dataset('iris')
iris.info()
#iris.boxplot()
#iris.hist()
iris.hist(edgecolor='black', linewidth=1.2)
#plt.show()
#iris.hist?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1a0dc470>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a8b45f8>]], dtype=object)

# %%
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length',data='iris')
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width',data='iris')
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length',data='iris')
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width',data='iris')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-5042b4eb3b4c> in <module>()
#       2 plt.figure(figsize=(12,8))
#       3 plt.subplot(2,2,1)
# ----> 4 sns.violinplot(x='species', y='sepal_length',data='iris')
#       5 plt.subplot(2,2,2)
#       6 sns.violinplot(x='species', y='sepal_width',data='iris')
#
# ~/Documents/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2343                              bw, cut, scale, scale_hue, gridsize,
#    2344                              width, inner, split, dodge, orient, linewidth,
# -> 2345                              color, palette, saturation)
#    2346
#    2347     if ax is None:
#
# ...

# %%
iris.boxplot(by='species', figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1a046198>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad19208>]], dtype=object)

# %%
pd.plotting.scatter_matrix(iris,figsize=(12,8))
plt.show()
