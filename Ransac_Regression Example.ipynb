# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt
sns.set(color_codes=True)
# %matplotlib inline
df = pd.read_csv("housing.data.txt",header=None, delim_whitespace=True)
col_name=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df.columns = col_name
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, size=4)
plt.show()

# %%
col_study=['CRIM','ZN','INDUS','RM','AGE']
sns.pairplot(df[col_study], size=4)
plt.show()

# %%
#COrrelation and feature selection
pd.options.display.float_format='{:,.2f}'.format
df.corr()
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
    1. CRIM      per capita crime rate by town
    2. ZN        proportion of residential land zoned for lots over 
                 25,000 sq.ft.
    3. INDUS     proportion of non-retail business acres per town
    4. CHAS      Charles River dummy variable (= 1 if tract bounds 
                 river; 0 otherwise)
    5. NOX       nitric oxides concentration (parts per 10 million)
    6. RM        average number of rooms per dwelling
    7. AGE       proportion of owner-occupied units built prior to 1940
    8. DIS       weighted distances to five Boston employment centres
    9. RAD       index of accessibility to radial highways
    10. TAX      full-value property-tax rate per $10,000
    11. PTRATIO  pupil-teacher ratio by town
    12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks 
                 by town
    13. LSTAT    % lower status of the population
    14. MEDV     Median value of owner-occupied homes in $1000's
# Out:
#   File "<ipython-input-37-249d4881473b>", line 3
#     1. CRIM      per capita crime rate by town
#     ^
# IndentationError: unexpected indent

# %%
X=df['RM'].values.reshape(-1,1)
Y=df['MEDV'].values
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,Y)

# %%
model.coef_
# Out:
# array([ 0.01289878])

# %%
model.intercept_
# Out:
# 0.41104424795099814

# %%
plt.figure(figsize=(8,6))
sns.regplot(X,Y)
plt.xlabel('Number of rooms-->')
plt.ylabel('Medium home values-->')
plt.title('Medum Home price vs Number of rooms')
plt.show()

# %%
Y=df['NOX'].values
X=df['INDUS'].values.reshape(-1,1)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([ 0.01289878])

# %%
model.intercept_
# Out:
# 0.41104424795099814

# %%
plt.figure(figsize=(10,5))
sns.regplot(X,Y)
plt.xlabel('Industries---->')
plt.ylabel('Nitrozen-->')
plt.title('Pollution vs. Industries')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt
sns.set(color_codes=True)
# %matplotlib inline
df = pd.read_csv("housing.data.txt",header=None, delim_whitespace=True)
col_name=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df.columns = col_name
Y=df['RM'].values
X=df['MEDV'].values.reshape(-1,1)
from sklearn.linear_model import RANSACRegressor
ransac=RANSACRegressor()
ransac.fit(X,Y)
inlier_mask=ransac.inlier_mask_
outlier_mask=np.logical_not(inlier_mask)
#np.arange(3,10,1)
line_X=np.arange(3,50,1)
line_Y_ransac = ransac.predict(line_X.reshape(-1,1))
sns.set(style='darkgrid', context='notebook',)
plt.figure(figsize=(10,6))
plt.scatter(X[inlier_mask],Y[inlier_mask], c='blue', marker='o', label='Inliers')
plt.scatter(Y[outlier_mask], Y[outlier_mask], c='brown', marker='s', label='Outliers')
plt.plot(line_X, line_Y_ransac,color='red')
plt.xlabel('Average number of rooms')
plt.ylabel('Medium house prize')
plt.legend(loc='upper center')
plt.title('Graph House prize vs Rooms')
plt.show()

# %%
ransac.estimator_.coef_
# Out:
# array([-1.77137636])

# %%
ransac.estimator_.intercept_
# Out:
# 117.84487303099556
